# %%
# !top
# Out:
# =top - 14:26:32 up 1 day, 27 min,  0 users,  load average: 1.84, 1.16, 0.57
# Tasks: 392 total,   2 running, 255 sleeping,   0 stopped,   0 zombie
# %Cpu(s):  0.2 us,  0.1 sy,  0.0 ni, 99.7 id,  0.0 wa,  0.0 hi,  0.0 si,  0.0 st
# KiB Mem : 65732852 total, 18891712 free, 46508384 used,   332756 buff/cache
# KiB Swap: 19200000+total, 15326822+free, 38731776 used. 18591592 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
# 19864 grohoto+  20   0 64.781g 0.042t   3936 R  89.5 68.9   2:31.60 python
# 29582 moyniha+  20   0   44340   3876   3020 R  10.5  0.0   0:00.05 top
#  1227 root      20   0 9956868   3616   3616 S   5.3  0.0   6:55.56 java
#     1 root      20   0  225976   3176   2760 S   0.0  0.0   0:03.58 systemd
#     2 root      20   0       0      0      0 S   0.0  0.0   0:00.03 kthreadd
#     3 root       0 -20       0      0      0 I   0.0  0.0   0:00.00 rcu_gp
# ...
